# %% [markdown]
# #Setup and Imports

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#!pip install opencv-contrib-python
# !pip install tqdm

# %%
import cv2
import tarfile
import os
import numpy as np
import pandas as pd
import pickle
from tqdm import tqdm #progress bars
import gc

#sampling
from collections import defaultdict # can group class without checking if key already exists
import random

#data
from sklearn.preprocessing import LabelEncoder
from pycocotools.coco import COCO
from collections import Counter

#clustering algs
from sklearn.cluster import MiniBatchKMeans
from sklearn.mixture import GaussianMixture
from sklearn.decomposition import PCA

#classifiers
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
#metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
#viz
import matplotlib.pyplot as plt

# %% [markdown]
# #Loading and sampling iCubWorld

# %%
def load_icub_from_drive():
    labels = []
    image_paths = []

    dataset_path = '/content/drive/MyDrive/U of Manchester/Robotics Assignment/data/icubworld_data'

    part_folders = [f for f in os.listdir(dataset_path) if f.startswith('part')]

    for part in part_folders:
        part_path = os.path.join(dataset_path, part)

        #class folders
        for class_name in os.listdir(part_path):
            class_path = os.path.join(part_path, class_name)
            if not os.path.isdir(class_path):
                continue

            #object instances
            for instance_name in os.listdir(class_path):
                instance_path = os.path.join(class_path, instance_name)

                if not os.path.isdir(instance_path):
                    continue

                # MIX transformation
                mix_path = os.path.join(instance_path, 'MIX')
                if not os.path.isdir(mix_path):
                    continue

                #go through days
                for day_name in os.listdir(mix_path):
                    day_path = os.path.join(mix_path, day_name)
                    if not os.path.isdir(day_path):
                        continue

                    #only left imags
                    left_path = os.path.join(day_path, 'left')
                    if not os.path.isdir(left_path):
                        continue

                    #get image file
                    for file in os.listdir(left_path):
                        if not file.lower().endswith(('.jpg', '.jpeg', '.png')):
                            continue

                        #now record label and image path for each image
                        img_path = os.path.join(left_path, file)
                        labels.append(class_name)  # use high-level class name
                        image_paths.append(img_path)
    return image_paths, labels

# %%
def sample_dataset(image_paths, labels, max_per_class=500, seed=42):
    #sample
    class_to_images = defaultdict(list)
    for path, label in zip(image_paths, labels):
        class_to_images[label].append(path)

    random.seed(seed)

    #get sample from each class
    sampled_image_paths = []
    sampled_labels = []

    for label, paths in class_to_images.items():
        random.shuffle(paths)
        selected = paths[:max_per_class]
        sampled_image_paths.extend(selected)
        sampled_labels.extend([label] * len(selected))

    # shuffle data -- avoid order bias
    combined = list(zip(sampled_image_paths, sampled_labels))
    random.shuffle(combined)
    sampled_image_paths, sampled_labels = zip(*combined)

    return list(sampled_image_paths), list(sampled_labels)

# %% [markdown]
# #Loading COCO

# %%
def build_image_label_map(coco, top_k=20, target_count=8000):
    img_ids = coco.getImgIds()
    temp_labels = {}
    cat_count = Counter()

    # most common object per image - no filtering yet
    for img_id in img_ids:
        anns = coco.loadAnns(coco.getAnnIds(imgIds=img_id))
        if not anns:
            continue
        cat_ids = [ann['category_id'] for ann in anns]
        most_common_cat = Counter(cat_ids).most_common(1)[0][0]
        fname = coco.loadImgs(img_id)[0]['file_name']
        temp_labels[fname] = most_common_cat
        cat_count[most_common_cat] += 1

    #get only the top k categories
    top_cats = set([cat for cat, _ in cat_count.most_common(top_k)])
    label_to_index = {cat_id: idx for idx, cat_id in enumerate(sorted(top_cats))}

    # get images from top_k categories only until target_count is reached
    image_label_map = {}
    class_image_counts = defaultdict(int)

    for fname, cat_id in temp_labels.items():
        if cat_id in top_cats:
            image_label_map[fname] = label_to_index[cat_id]
            class_image_counts[cat_id] += 1
            if len(image_label_map) >= target_count:
                break

    return image_label_map, label_to_index

# %%
def paths_and_labels(image_label_map, img_dir):
    paths = []
    labels = []
    for fname, label in image_label_map.items():
        path = os.path.join(img_dir, fname)
        if os.path.exists(path):
            paths.append(path)
            labels.append(label)
    return paths, labels

# %% [markdown]
# # Feature extractor methods - 2 choices (SIFT, ORB)

# %%
#CHOICE 1: SIFT
def get_sift_descriptors(image_paths, resize_to=(256, 256)):
    sift = cv2.SIFT_create()
    img_descriptors = []
    all_descriptors = []

    for path in tqdm(image_paths, desc="Extracting SIFT descriptors"):
        img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
        if resize_to:
            img = cv2.resize(img, resize_to)

        #this finds DoG interest point (sparse)
        keypoints, descriptors = sift.detectAndCompute(img, None)

        if descriptors is not None:
            img_descriptors.append(descriptors)
            all_descriptors.extend(descriptors)
        else:
            img_descriptors.append(np.array([]))

    return all_descriptors, img_descriptors

# %%
#CHOICE 2: ORB
def get_orb_descriptors(image_paths, resize_to=(256, 256), max_features=1500):
    orb = cv2.ORB_create(nfeatures=max_features)
    img_descriptors = []
    all_descriptors = []

    for path in tqdm(image_paths, desc="Extracting ORB descriptors"):
        img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
        if resize_to:
            img = cv2.resize(img, resize_to)

        keypoints, descriptors = orb.detectAndCompute(img, None)

        if descriptors is not None:
            img_descriptors.append(descriptors)
            all_descriptors.extend(descriptors)
        else:
            img_descriptors.append(np.array([]))

    return all_descriptors, img_descriptors

# %% [markdown]
# # Clustering algorithm functions (building visual vocab) -- 2 choices (KMeans, Gaussian Mixture Models)

# %%
#CHOICE 1: KMEANS
def build_histograms_kmeans(descriptors, kmeans, k):
    #initalize hist
    hist = np.zeros(k)
    if descriptors is not None and len(descriptors) > 0:
        words_in_image = kmeans.predict(descriptors)
        #update histogram (word is an id)
        for word in words_in_image:
            hist[word] += 1
    return hist

# %%
#CHOICE 2: GMM
def build_histograms_gmm(descriptors, gmm, k):
    hist = np.zeros(k)
    if descriptors is not None and len(descriptors) > 0:
        words_in_image = gmm.predict(descriptors)
        for word in words_in_image:
            hist[word] += 1
    return hist

# %% [markdown]
# # Image classifiers functions -- 2 choices (SVM, naive bayes)

# %%
def evaluate_classifier(X_train, y_train, X_val, y_val, classifier='svm'):

    if classifier == 'svm':
        model = SVC(kernel='linear', random_state=42)
    elif classifier == 'nb':
        model = GaussianNB()
    else:
        raise ValueError("Unsupported classifier.")

    model.fit(X_train, y_train)
    y_pred = model.predict(X_val)

    accuracy = accuracy_score(y_val, y_pred)
    precision = precision_score(y_val, y_pred, average='macro', zero_division=0)
    recall = recall_score(y_val, y_pred, average='macro', zero_division=0)
    f1 = f1_score(y_val, y_pred, average='macro', zero_division=0)

    print(f"{classifier.upper()} Results:")
    print(f"  Accuracy : {accuracy:.4f}")
    print(f"  Precision: {precision:.4f}")
    print(f"  Recall   : {recall:.4f}")
    print(f"  F1-score : {f1:.4f}")

    return model, {'accuracy': accuracy, 'precision': precision, 'recall': recall, 'f1': f1}

# %% [markdown]
# # Experiments (24 total)

# %% [markdown]
# ## RUN SIFT and ORB once, so I can reload in the future

# %%
# #RUN SIFT ONCE
# all_descriptors, image_descriptors = get_sift_descriptors(sampled_image_paths)
# # save
# with open("sift_descriptors_icub.pkl", "wb") as f:
#     pickle.dump((image_descriptors, all_descriptors), f)

# %%
# #RUN ORB
# # RUN ORB ONCE
# all_descriptors, image_descriptors = get_orb_descriptors(sampled_image_paths)

# # Save to file
# with open("orb_descriptors_icub.pkl", "wb") as f:
#     pickle.dump((image_descriptors, all_descriptors), f)

# %% [markdown]
# ###CHECK that the .pkl files look *correct*

# %%
# # -- load descriptors for each method (SIFT and ORB)-- #
# with open("sift_descriptors_icub.pkl", "rb") as f:
#     sift_image_descriptors, sift_all_descriptors = pickle.load(f)
# with open("orb_descriptors_icub.pkl", "rb") as f:
#     orb_image_descriptors, orb_all_descriptors = pickle.load(f)

# %%
# print("SIFT:")
# print(f"  Total images: {len(sift_image_descriptors)}")
# print(f"  Total descriptors: {len(sift_all_descriptors)}")
# print(f"  Descriptors from first image: {sift_image_descriptors[0].shape if len(sift_image_descriptors[0]) > 0 else 'None'}")

# print("\nORB:")
# print(f"  Total images: {len(orb_image_descriptors)}")
# print(f"  Total descriptors: {len(orb_all_descriptors)}")
# print(f"  Descriptors from first image: {orb_image_descriptors[0].shape if len(orb_image_descriptors[0]) > 0 else 'None'}")

# %%
# #VISUALIZE SIFT

# # Load an image
# img_path = sampled_image_paths[0]
# img = cv2.imread(img_path)
# gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# # Recompute SIFT keypoints for comparison
# sift = cv2.SIFT_create()
# keypoints, _ = sift.detectAndCompute(gray, None)

# # Draw keypoints
# img_with_kp = cv2.drawKeypoints(img, keypoints, None, flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

# plt.figure(figsize=(8, 6))
# plt.imshow(cv2.cvtColor(img_with_kp, cv2.COLOR_BGR2RGB))
# plt.title("SIFT Keypoints")
# plt.axis('off')
# plt.show()

# %%
# ##VISUALIZE ORB
# # Pick a sample image path
# img_path = sampled_image_paths[0]

# # Load the image
# img = cv2.imread(img_path)
# gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# # Detect ORB keypoints
# orb = cv2.ORB_create()
# keypoints, _ = orb.detectAndCompute(gray, None)

# # Draw keypoints
# img_with_kp = cv2.drawKeypoints(img, keypoints, None, flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

# # Display
# plt.figure(figsize=(8, 6))
# plt.imshow(cv2.cvtColor(img_with_kp, cv2.COLOR_BGR2RGB))
# plt.title("ORB Keypoints")
# plt.axis('off')
# plt.show()

# %%
##old code -- delete soon
# -- run for each feature extraction method -- #
# for feature_method in feature_methods:

#     if feature_method == 'sift':
#         image_descriptors = sift_image_descriptors
#         all_descriptors = sift_all_descriptors
#     elif feature_method == 'orb':
#         image_descriptors = orb_image_descriptors
#         all_descriptors = orb_all_descriptors
#     else:
#         raise ValueError("Unsupported feature extraction method.")

# %% [markdown]
# ##EXPERIMENTS iCubWorld -- 2 feature methods, 3 vocab sizes, 2 clustering methods, 2 classifiers

# %%
vocab_sizes = [100, 250, 500]
classifiers = ['svm', 'nb']
results = []
cluster_methods = ['kmeans','gmm']
feature_methods = ['sift','orb']
data = 'coco' ##SWITCH DATASET HERE

if data == 'icubworld':
    #LOAD icubworld data
    image_paths, labels = load_icub_from_drive()
    sampled_image_paths, sampled_labels = sample_dataset(image_paths, labels, max_per_class=500)

    #label encoder helps map between labels and unique IDs -- easy to convert back and forth
    label_encoder = LabelEncoder()
    encoded_labels = label_encoder.fit_transform(sampled_labels)

    #split
    image_paths_trainval, image_paths_test, y_trainval, y_test = train_test_split(
    sampled_image_paths, sampled_labels, test_size=0.1, stratify=sampled_labels, random_state=42
    )
    image_paths_train, image_paths_val, y_train, y_val = train_test_split(
        image_paths_trainval, y_trainval, test_size=0.2, stratify=y_trainval, random_state=42
    )

elif data == 'coco':
    annotation_path_val = '/content/drive/MyDrive/U of Manchester/Robotics Assignment/data/coco/annotations/instances_val2017.json'
    annotation_path_train = '/content/drive/MyDrive/U of Manchester/Robotics Assignment/data/coco/annotations/instances_train2017.json'
    coco_val = COCO(annotation_path_val)
    coco_train = COCO(annotation_path_train)

    #coco only has train and val
    train_image_label_map, train_label_to_index = build_image_label_map(coco_train, target_count=8000)
    val_image_label_map,   val_label_to_index   = build_image_label_map(coco_val, target_count=2000)

    all_labels = set(train_image_label_map.values()) | set(val_image_label_map.values())
    label_encoder = LabelEncoder()
    label_encoder.fit(list(sorted(all_labels)))

    local_train_path = "/content/train2017"
    local_val_path   = "/content/val2017"

    # unzip
    if not os.path.exists(local_train_path):
        print("Unzipping training images...")
        # !unzip -q "/content/drive/MyDrive/U of Manchester/Robotics Assignment/data/train2017.zip" -d /content/
    if not os.path.exists(local_val_path):
        print("Unzipping validation images...")
        # !unzip -q "/content/drive/MyDrive/U of Manchester/Robotics Assignment/data/val2017.zip" -d /content/

    image_paths_train, y_train = paths_and_labels(train_image_label_map, local_train_path)
    image_paths_val, y_val = paths_and_labels(val_image_label_map, local_val_path)

    # encode labels
    train_labels = label_encoder.transform(train_labels)
    val_labels  = label_encoder.transform(val_labels)

print("Dataset: ", data)
print("Train images:", len(image_paths_train))
print("Val images:  ", len(image_paths_val))

#note no test labels are released for coco
if data == 'icubworld':
  print("Test images: ", len(image_paths_test))

for feature_method in feature_methods:
    # extract descriptors
    if feature_method == 'sift':
        all_descriptors_train, image_descriptors_train = get_sift_descriptors(image_paths_train)
        _, image_descriptors_val = get_sift_descriptors(image_paths_val)

    elif feature_method == 'orb':
        all_descriptors_train, image_descriptors_train = get_orb_descriptors(image_paths_train)
        _, image_descriptors_val = get_orb_descriptors(image_paths_val)

    all_descriptors_train = np.array(all_descriptors_train, dtype=np.float32)

    for clustering_alg in cluster_methods:
      #one run for each vocab size
      for k in vocab_sizes:
          if clustering_alg == 'kmeans':
              kmeans = MiniBatchKMeans(n_clusters=k, random_state=42, batch_size=1000, verbose=1)
              kmeans.fit(all_descriptors_train.astype(np.float32))
              X = [] #each row is histogram of visual words for one image

              X_train = [build_histograms_kmeans(d.astype(np.float32), kmeans, k) if len(d) > 0 else np.zeros(k)
                        for d in image_descriptors_train]
              X_val = [build_histograms_kmeans(d.astype(np.float32), kmeans, k) if len(d) > 0 else np.zeros(k)
                      for d in image_descriptors_val]
          elif clustering_alg == 'gmm':
              #take samle of descriptors bc colab keeps crashing
              sample_size = 100000
              if len(all_descriptors_train) > sample_size:
                  indices = np.random.choice(len(all_descriptors_train), sample_size, replace=False)
                  sampled_descriptors = all_descriptors_train[indices]
              else:
                  sampled_descriptors = all_descriptors_train

              #add pca to reduce dimensionality
              pca = PCA(n_components=16 if feature_method == 'orb' else 64, random_state=42) #why is this the case?
              pca.fit(sampled_descriptors)
              pca_all_descriptors = pca.transform(sampled_descriptors)

              gmm = GaussianMixture(n_components=k, random_state=42, verbose=1, covariance_type='diag')
              gmm.fit(pca_all_descriptors)

              X_train = []
              for d in image_descriptors_train:
                  if d is None or len(d) == 0:
                      X_train.append(np.zeros(k))
                  else:
                      d_pca = pca.transform(d.astype(np.float32))
                      X_train.append(build_histograms_gmm(d_pca, gmm, k))
              X_val = []
              for d in image_descriptors_val:
                  if d is None or len(d) == 0:
                      X_val.append(np.zeros(k))
                  else:
                      d_pca = pca.transform(d.astype(np.float32))
                      X_val.append(build_histograms_gmm(d_pca, gmm, k))

          for classifier in classifiers:
              model, metrics = evaluate_classifier(X_train, y_train, X_val, y_val, classifier=classifier)
              results.append({
                    'feature': feature_method,
                    'clustering': clustering_alg,
                    'vocab_size': k,
                    'classifier': classifier,
                    **metrics
                })
              print(f"[{feature_method.upper()} | {clustering_alg.upper()} | k={k} | {classifier.upper()}] "
                      f"Accuracy: {metrics['accuracy']:.4f}, F1: {metrics['f1']:.4f}")
              #reduce memory
              del model, metrics
              gc.collect()
          #CLEANUP MEMORY -- colab is crashing from high ram
          del X_train, X_val
          if clustering_alg == 'kmeans':
              del kmeans
          elif clustering_alg == 'gmm':
              del gmm, pca
          gc.collect()

df = pd.DataFrame(results)
df.to_csv(f"{feature_method}_experiments_results.csv", index=False)
print("\nsaved results!'")
# Out:
# loading annotations into memory...
# Done (t=1.31s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=34.08s)
# creating index...
# index created!
# Dataset:  coco
# Train images: 8000
# Val images:   2000
# Extracting SIFT descriptors: 100%|██████████| 8000/8000 [03:11<00:00, 41.77it/s]
# Extracting SIFT descriptors: 100%|██████████| 2000/2000 [00:46<00:00, 43.27it/s]
# Streaming output truncated to the last 5000 lines.
# Minibatch step 1492/336270: mean batch inertia: 73678.744, ewa inertia: 81762.33309061355
# Minibatch step 1493/336270: mean batch inertia: 74220.296, ewa inertia: 81757.84740074401
# Minibatch step 1494/336270: mean batch inertia: 74671.096, ewa inertia: 81753.63249586029
# Minibatch step 1495/336270: mean batch inertia: 72757.136, ewa inertia: 81748.28175405036
# Minibatch step 1496/336270: mean batch inertia: 73402.488, ewa inertia: 81743.31802315828
# Minibatch step 1497/336270: mean batch inertia: 73819.888, ewa inertia: 81738.6054966406
# Minibatch step 1498/336270: mean batch inertia: 74890.96, ewa inertia: 81734.53280200048
# Minibatch step 1499/336270: mean batch inertia: 72711.016, ewa inertia: 81729.16598963665
# Minibatch step 1500/336270: mean batch inertia: 73061.624, ewa inertia: 81724.01089628063
# Minibatch step 1501/336270: mean batch inertia: 74181.704, ewa inertia: 81719.5250459419
# Minibatch step 1502/336270: mean batch inertia: 72983.952, ewa inertia: 81714.32949054406
# Minibatch step 1503/336270: mean batch inertia: 73860.8, ewa inertia: 81709.65853795489
# Minibatch step 1504/336270: mean batch inertia: 73008.176, ewa inertia: 81704.48325817284
# Minibatch step 1505/336270: mean batch inertia: 74742.04, ewa inertia: 81700.34228660041
# Minibatch step 1506/336270: mean batch inertia: 72874.112, ewa inertia: 81695.09281204769
# Minibatch step 1507/336270: mean batch inertia: 72473.584, ewa inertia: 81689.60824227388
# Minibatch step 1508/336270: mean batch inertia: 74768.536, ewa inertia: 81685.49187646044
# Minibatch step 1509/336270: mean batch inertia: 74052.576, ewa inertia: 81680.95213567014
# Minibatch step 1510/336270: mean batch inertia: 74530.528, ewa inertia: 81676.69936089286
# Minibatch step 1511/336270: mean batch inertia: 73620.696, ewa inertia: 81671.9079852697
# Minibatch step 1512/336270: mean batch inertia: 72964.28, ewa inertia: 81666.72905043128
# Minibatch step 1513/336270: mean batch inertia: 73204.608, ewa inertia: 81661.6961329032
# Minibatch step 1514/336270: mean batch inertia: 73563.248, ewa inertia: 81656.8795128956
# Minibatch step 1515/336270: mean batch inertia: 74163.992, ewa inertia: 81652.42305514998
# Minibatch step 1516/336270: mean batch inertia: 73676.472, ewa inertia: 81647.67929130764
# Minibatch step 1517/336270: mean batch inertia: 74045.664, ewa inertia: 81643.15792889976
# Minibatch step 1518/336270: mean batch inertia: 75270.544, ewa inertia: 81639.36776327211
# Minibatch step 1519/336270: mean batch inertia: 73239.248, ewa inertia: 81634.37172153003
# Minibatch step 1520/336270: mean batch inertia: 73542.72, ewa inertia: 81629.55914374512
# Minibatch step 1521/336270: mean batch inertia: 73956.976, ewa inertia: 81624.99581051464
# Minibatch step 1522/336270: mean batch inertia: 74420.488, ewa inertia: 81620.71086901776
# Minibatch step 1523/336270: mean batch inertia: 72828.432, ewa inertia: 81615.48158735564
# Minibatch step 1524/336270: mean batch inertia: 73044.992, ewa inertia: 81610.38421673056
# Minibatch step 1525/336270: mean batch inertia: 73203.144, ewa inertia: 81605.383940039
# Minibatch step 1526/336270: mean batch inertia: 72948.8, ewa inertia: 81600.23536407495
# Minibatch step 1527/336270: mean batch inertia: 74297.888, ewa inertia: 81595.89223168229
# Minibatch step 1528/336270: mean batch inertia: 72567.64, ewa inertia: 81590.5226028819
# Minibatch step 1529/336270: mean batch inertia: 72367.736, ewa inertia: 81585.03727313127
# Minibatch step 1530/336270: mean batch inertia: 73750.416, ewa inertia: 81580.37756636314
# Minibatch step 1531/336270: mean batch inertia: 74174.192, ewa inertia: 81575.97267532803
# Minibatch step 1532/336270: mean batch inertia: 74025.64, ewa inertia: 81571.48205158983
# Minibatch step 1533/336270: mean batch inertia: 73139.792, ewa inertia: 81566.46723315376
# Minibatch step 1534/336270: mean batch inertia: 72778.608, ewa inertia: 81561.24058010717
# Minibatch step 1535/336270: mean batch inertia: 73439.624, ewa inertia: 81556.41018047111
# Minibatch step 1536/336270: mean batch inertia: 73941.728, ewa inertia: 81551.88128432457
# Minibatch step 1537/336270: mean batch inertia: 73098.592, ewa inertia: 81546.85361956352
# Minibatch step 1538/336270: mean batch inertia: 73203.44, ewa inertia: 81541.89130427642
# Minibatch step 1539/336270: mean batch inertia: 74143.0, ewa inertia: 81537.49075156491
# Minibatch step 1540/336270: mean batch inertia: 75256.784, ewa inertia: 81533.75524850246
# Minibatch step 1541/336270: mean batch inertia: 73789.888, ewa inertia: 81529.1495184523
# Minibatch step 1542/336270: mean batch inertia: 73442.544, ewa inertia: 81524.33994193903
# Minibatch step 1543/336270: mean batch inertia: 73708.72, ewa inertia: 81519.69153637212
# Minibatch step 1544/336270: mean batch inertia: 72886.872, ewa inertia: 81514.55709448663
# Minibatch step 1545/336270: mean batch inertia: 72322.48, ewa inertia: 81509.09002947391
# Minibatch step 1546/336270: mean batch inertia: 74747.232, ewa inertia: 81505.06835765002
# Minibatch step 1547/336270: mean batch inertia: 73436.112, ewa inertia: 81500.26927812329
# Minibatch step 1548/336270: mean batch inertia: 73511.424, ewa inertia: 81495.5178453336
# Minibatch step 1549/336270: mean batch inertia: 73566.664, ewa inertia: 81490.80209295214
# Minibatch step 1550/336270: mean batch inertia: 74244.688, ewa inertia: 81486.49240576952
# Minibatch step 1551/336270: mean batch inertia: 73202.136, ewa inertia: 81481.56521525605
# Minibatch step 1552/336270: mean batch inertia: 74232.896, ewa inertia: 81477.25400839299
# Minibatch step 1553/336270: mean batch inertia: 73292.768, ewa inertia: 81472.3862166367
# Minibatch step 1554/336270: mean batch inertia: 74864.064, ewa inertia: 81468.45586152631
# Minibatch step 1555/336270: mean batch inertia: 73681.128, ewa inertia: 81463.82428291172
# Minibatch step 1556/336270: mean batch inertia: 73112.112, ewa inertia: 81458.85703192493
# Minibatch step 1557/336270: mean batch inertia: 73192.048, ewa inertia: 81453.94027785936
# Minibatch step 1558/336270: mean batch inertia: 73829.96, ewa inertia: 81449.40585159135
# Minibatch step 1559/336270: mean batch inertia: 72740.032, ewa inertia: 81444.22587838427
# Minibatch step 1560/336270: mean batch inertia: 73232.896, ewa inertia: 81439.34212101097
# Minibatch step 1561/336270: mean batch inertia: 73896.344, ewa inertia: 81434.85585956053
# Minibatch step 1562/336270: mean batch inertia: 73767.176, ewa inertia: 81430.29544259947
# Minibatch step 1563/336270: mean batch inertia: 73065.872, ewa inertia: 81425.32063154376
# Minibatch step 1564/336270: mean batch inertia: 72587.224, ewa inertia: 81420.06409938277
# Minibatch step 1565/336270: mean batch inertia: 73769.88, ewa inertia: 81415.51408817194
# Minibatch step 1566/336270: mean batch inertia: 73102.712, ewa inertia: 81410.5699793501
# Minibatch step 1567/336270: mean batch inertia: 72914.656, ewa inertia: 81405.51696319388
# Minibatch step 1638/336270: mean batch inertia: 75087.992, ewa inertia: 81085.82165002386
# Minibatch step 1639/336270: mean batch inertia: 73407.976, ewa inertia: 81081.2551868736
# Minibatch step 1640/336270: mean batch inertia: 73456.56, ewa inertia: 81076.72033540746
# Minibatch step 1641/336270: mean batch inertia: 73652.392, ewa inertia: 81072.30465380814
# Minibatch step 1642/336270: mean batch inertia: 74188.968, ewa inertia: 81068.21073155268
# Minibatch step 1643/336270: mean batch inertia: 74170.224, ewa inertia: 81064.10809604052
# Minibatch step 1644/336270: mean batch inertia: 73983.776, ewa inertia: 81059.89700909218
# Minibatch step 1645/336270: mean batch inertia: 73083.376, ewa inertia: 81055.15290626494
# Minibatch step 1646/336270: mean batch inertia: 73624.76, ewa inertia: 81050.7336177112
# Minibatch step 1647/336270: mean batch inertia: 73602.424, ewa inertia: 81046.30367304294
# Minibatch step 1648/336270: mean batch inertia: 72871.52, ewa inertia: 81041.44165183205
# Minibatch step 1649/336270: mean batch inertia: 73772.808, ewa inertia: 81037.11857095273
# Minibatch step 1650/336270: mean batch inertia: 73291.4, ewa inertia: 81032.51173981301
# Minibatch step 1651/336270: mean batch inertia: 73852.392, ewa inertia: 81028.24130332588
# Minibatch step 1652/336270: mean batch inertia: 73792.168, ewa inertia: 81023.93758798717
# Minibatch step 1653/336270: mean batch inertia: 73493.208, ewa inertia: 81019.45862334974
# Minibatch step 1654/336270: mean batch inertia: 75012.48, ewa inertia: 81015.8859223893
# Minibatch step 1655/336270: mean batch inertia: 73528.128, ewa inertia: 81011.43251551068
# Minibatch step 1656/336270: mean batch inertia: 73103.64, ewa inertia: 81006.72928953193
# Minibatch step 1657/336270: mean batch inertia: 73767.08, ewa inertia: 81002.4234473454
# Minibatch step 1658/336270: mean batch inertia: 73605.408, ewa inertia: 80998.02401031554
# Minibatch step 1659/336270: mean batch inertia: 72567.64, ewa inertia: 80993.00996865847
# Minibatch step 1660/336270: mean batch inertia: 72807.088, ewa inertia: 80988.14132285277
# Minibatch step 1661/336270: mean batch inertia: 72536.544, ewa inertia: 80983.1146644
# Minibatch step 1662/336270: mean batch inertia: 72543.712, ewa inertia: 80978.09525882272
# Minibatch step 1663/336270: mean batch inertia: 74953.0, ewa inertia: 80974.51178284126
# Minibatch step 1664/336270: mean batch inertia: 73424.592, ewa inertia: 80970.02140467435
# Minibatch step 1665/336270: mean batch inertia: 73214.12, ewa inertia: 80965.4085172088
# Minibatch step 1666/336270: mean batch inertia: 74929.36, ewa inertia: 80961.81852668495
# Minibatch step 1667/336270: mean batch inertia: 73275.488, ewa inertia: 80957.24701708305
# Minibatch step 1668/336270: mean batch inertia: 74204.528, ewa inertia: 80953.23078076348
# Minibatch step 1669/336270: mean batch inertia: 73739.952, ewa inertia: 80948.94062265841
# Minibatch step 1670/336270: mean batch inertia: 73022.528, ewa inertia: 80944.22632221463
# Minibatch step 1671/336270: mean batch inertia: 73987.84, ewa inertia: 80940.0889530557
# Minibatch step 1672/336270: mean batch inertia: 74858.088, ewa inertia: 80936.47163193491
# Minibatch step 1673/336270: mean batch inertia: 72932.816, ewa inertia: 80931.71139056297
# Minibatch step 1674/336270: mean batch inertia: 72789.92, ewa inertia: 80926.86899178903
# Minibatch step 1675/336270: mean batch inertia: 72946.272, ewa inertia: 80922.12246473687
# Minibatch step 1676/336270: mean batch inertia: 73629.304, ewa inertia: 80917.78499973706
# Minibatch step 1677/336270: mean batch inertia: 73638.0, ewa inertia: 80913.45528649999
# Minibatch step 1678/336270: mean batch inertia: 72581.904, ewa inertia: 80908.50002643504
# Minibatch step 1679/336270: mean batch inertia: 73407.824, ewa inertia: 80904.03893640562
# Minibatch step 1680/336270: mean batch inertia: 72107.968, ewa inertia: 80898.80739937958
# Minibatch step 1681/336270: mean batch inertia: 73902.704, ewa inertia: 80894.64640815562
# Minibatch step 1682/336270: mean batch inertia: 75908.312, ewa inertia: 80891.68074390972
# Minibatch step 1683/336270: mean batch inertia: 72697.16, ewa inertia: 80886.80698391025
# Minibatch step 1684/336270: mean batch inertia: 74478.096, ewa inertia: 80882.99534925612
# Minibatch step 1685/336270: mean batch inertia: 73544.848, ewa inertia: 80878.63092452176
# Minibatch step 1686/336270: mean batch inertia: 73006.704, ewa inertia: 80873.94902990431
# Minibatch step 1687/336270: mean batch inertia: 73255.344, ewa inertia: 80869.41780061014
# Minibatch step 1688/336270: mean batch inertia: 73706.224, ewa inertia: 80865.15743096743
# Minibatch step 1689/336270: mean batch inertia: 74093.328, ewa inertia: 80861.1298285688
# Minibatch step 1690/336270: mean batch inertia: 73503.312, ewa inertia: 80856.75370465172
# Minibatch step 1691/336270: mean batch inertia: 73519.56, ewa inertia: 80852.38984710549
# Minibatch step 1692/336270: mean batch inertia: 74391.272, ewa inertia: 80848.54704302954
# Minibatch step 1693/336270: mean batch inertia: 73412.6, ewa inertia: 80844.12445110634
# Minibatch step 1694/336270: mean batch inertia: 74357.872, ewa inertia: 80840.26669801369
# Minibatch step 1695/336270: mean batch inertia: 74385.248, ewa inertia: 80836.42752145787
# Minibatch step 1696/336270: mean batch inertia: 73733.096, ewa inertia: 80832.20275540819
# Minibatch step 1697/336270: mean batch inertia: 73972.008, ewa inertia: 80828.12259699107
# Minibatch step 1698/336270: mean batch inertia: 72813.104, ewa inertia: 80823.35559740028
# Minibatch step 1699/336270: mean batch inertia: 73515.28, ewa inertia: 80819.00905809276
# Minibatch step 1700/336270: mean batch inertia: 73901.04, ewa inertia: 80814.89453792416
# Minibatch step 1701/336270: mean batch inertia: 74268.672, ewa inertia: 80811.00111711897
# Minibatch step 1702/336270: mean batch inertia: 73709.664, ewa inertia: 80806.77753725802
# Minibatch step 1703/336270: mean batch inertia: 74267.344, ewa inertia: 80802.88815426796
# Minibatch step 1704/336270: mean batch inertia: 74557.296, ewa inertia: 80799.17353590702
# Minibatch step 1705/336270: mean batch inertia: 73741.72, ewa inertia: 80794.97605617436
# Minibatch step 1706/336270: mean batch inertia: 73985.136, ewa inertia: 80790.92584663731
# Minibatch step 1707/336270: mean batch inertia: 73782.936, ewa inertia: 80786.75778584907
# Minibatch step 1708/336270: mean batch inertia: 74394.856, ewa inertia: 80782.95614860658
# Minibatch step 1709/336270: mean batch inertia: 74330.784, ewa inertia: 80779.11866505991
# Minibatch step 1710/336270: mean batch inertia: 73465.584, ewa inertia: 80774.76887892607
# Minibatch step 1711/336270: mean batch inertia: 73841.808, ewa inertia: 80770.64544224618
# Minibatch step 1712/336270: mean batch inertia: 73418.032, ewa inertia: 80766.27241368158
# Minibatch step 1713/336270: mean batch inertia: 74269.84, ewa inertia: 80762.40860597073
# Minibatch step 1714/336270: mean batch inertia: 74120.176, ewa inertia: 80758.45808237162
# Minibatch step 1715/336270: mean batch inertia: 74186.848, ewa inertia: 80754.54956211126
# Minibatch step 1716/336270: mean batch inertia: 74758.624, ewa inertia: 80750.98343505176
# Minibatch step 1717/336270: mean batch inertia: 73679.848, ewa inertia: 80746.77781789473
# Minibatch step 1718/336270: mean batch inertia: 74331.848, ewa inertia: 80742.9624845369
# Minibatch step 1719/336270: mean batch inertia: 73497.736, ewa inertia: 80738.65332526682
# Minibatch step 1720/336270: mean batch inertia: 74684.256, ewa inertia: 80735.05242163535
# Minibatch step 1721/336270: mean batch inertia: 74221.776, ewa inertia: 80731.17859580937
# Minibatch step 1722/336270: mean batch inertia: 73434.512, ewa inertia: 80726.83884210131
# Minibatch step 1723/336270: mean batch inertia: 73937.992, ewa inertia: 80722.80111845455
# Minibatch step 1724/336270: mean batch inertia: 73085.296, ewa inertia: 80718.25864817406
# Minibatch step 1725/336270: mean batch inertia: 72266.192, ewa inertia: 80713.23171058611
# Minibatch step 1726/336270: mean batch inertia: 74012.024, ewa inertia: 80709.2461110485
# Minibatch step 1727/336270: mean batch inertia: 73723.6, ewa inertia: 80705.09133938455
# Minibatch step 1728/336270: mean batch inertia: 74054.656, ewa inertia: 80701.13593714089
# Minibatch step 1729/336270: mean batch inertia: 73017.392, ewa inertia: 80696.56596593485
# Minibatch step 1730/336270: mean batch inertia: 74336.256, ewa inertia: 80692.78311819244
# Minibatch step 1731/336270: mean batch inertia: 74866.2, ewa inertia: 80689.31770897299
# Minibatch step 1732/336270: mean batch inertia: 73384.536, ewa inertia: 80684.97312873325
# Minibatch step 1733/336270: mean batch inertia: 73822.104, ewa inertia: 80680.89137971016
# Minibatch step 1734/336270: mean batch inertia: 73510.512, ewa inertia: 80676.62673638397
# Minibatch step 1735/336270: mean batch inertia: 74153.776, ewa inertia: 80672.74721615393
# Minibatch step 1736/336270: mean batch inertia: 74021.024, ewa inertia: 80668.79104793475
# Minibatch step 1737/336270: mean batch inertia: 74007.016, ewa inertia: 80664.82890130425
# Minibatch step 1738/336270: mean batch inertia: 72291.296, ewa inertia: 80659.8486723215
# Minibatch step 1739/336270: mean batch inertia: 73437.6, ewa inertia: 80655.55317929812
# Minibatch step 1740/336270: mean batch inertia: 74636.408, ewa inertia: 80651.9732421764
# Minibatch step 1741/336270: mean batch inertia: 73912.888, ewa inertia: 80647.9651146589
# Minibatch step 2021/336270: mean batch inertia: 74431.728, ewa inertia: 79559.32234020729
# ...
# Minibatch step 14690/802009: mean batch inertia: 91174.624, ewa inertia: 91658.97476417618
# Minibatch step 14691/802009: mean batch inertia: 91420.352, ewa inertia: 91658.91525793505
# Minibatch step 14692/802009: mean batch inertia: 92139.776, ewa inertia: 91659.0351719565
# Minibatch step 14693/802009: mean batch inertia: 90456.4, ewa inertia: 91658.73526637636
# Minibatch step 14694/802009: mean batch inertia: 91678.712, ewa inertia: 91658.74024804829
# Minibatch step 14695/802009: mean batch inertia: 91223.792, ewa inertia: 91658.63178339525
# Minibatch step 14696/802009: mean batch inertia: 91498.624, ewa inertia: 91658.59188166259
# Minibatch step 14697/802009: mean batch inertia: 91616.784, ewa inertia: 91658.58145587654
# Minibatch step 14698/802009: mean batch inertia: 90584.76, ewa inertia: 91658.31367304914
# Minibatch step 14699/802009: mean batch inertia: 90421.096, ewa inertia: 91658.00514350283
# Minibatch step 14700/802009: mean batch inertia: 89058.416, ewa inertia: 91657.35687434494
# Minibatch step 14701/802009: mean batch inertia: 91549.44, ewa inertia: 91657.32996271491
# Minibatch step 14702/802009: mean batch inertia: 91875.352, ewa inertia: 91657.38433167657
# Minibatch step 14703/802009: mean batch inertia: 92060.464, ewa inertia: 91657.48484914402
# Minibatch step 14704/802009: mean batch inertia: 91471.16, ewa inertia: 91657.43838462737
# Minibatch step 14705/802009: mean batch inertia: 90211.216, ewa inertia: 91657.07773480324
# Minibatch step 14706/802009: mean batch inertia: 91733.76, ewa inertia: 91657.09685734328
# Minibatch step 14707/802009: mean batch inertia: 91529.752, ewa inertia: 91657.06510088527
# Minibatch step 14708/802009: mean batch inertia: 91605.04, ewa inertia: 91657.05212719347
# Minibatch step 14709/802009: mean batch inertia: 89978.648, ewa inertia: 91656.6335773496
# Minibatch step 14710/802009: mean batch inertia: 90017.808, ewa inertia: 91656.22489735506
# Minibatch step 14711/802009: mean batch inertia: 91503.6, ewa inertia: 91656.18683672
# Minibatch step 14712/802009: mean batch inertia: 91803.2, ewa inertia: 91656.22349793617
# Minibatch step 14713/802009: mean batch inertia: 90517.184, ewa inertia: 91655.93945144444
# Minibatch step 14714/802009: mean batch inertia: 91812.16, ewa inertia: 91655.97840874032
# Minibatch step 14715/802009: mean batch inertia: 92057.12, ewa inertia: 91656.07844290233
# Minibatch step 14716/802009: mean batch inertia: 90419.504, ewa inertia: 91655.7700737607
# Minibatch step 14717/802009: mean batch inertia: 90949.824, ewa inertia: 91655.59402937771
# Minibatch step 14718/802009: mean batch inertia: 89515.008, ewa inertia: 91655.06022352376
# Minibatch step 14719/802009: mean batch inertia: 89775.64, ewa inertia: 91654.5915455526
# Minibatch step 14720/802009: mean batch inertia: 90224.544, ewa inertia: 91654.2349293079
# Minibatch step 14721/802009: mean batch inertia: 91695.76, ewa inertia: 91654.24528456834
# Minibatch step 14722/802009: mean batch inertia: 91808.768, ewa inertia: 91654.2838184693
# Minibatch step 14723/802009: mean batch inertia: 90939.024, ewa inertia: 91654.10545148335
# Minibatch step 14724/802009: mean batch inertia: 91562.784, ewa inertia: 91654.08267831529
# Minibatch step 14725/802009: mean batch inertia: 91538.8, ewa inertia: 91654.05392984748
# Minibatch step 14726/802009: mean batch inertia: 91624.584, ewa inertia: 91654.04658082209
# Minibatch step 14727/802009: mean batch inertia: 91739.632, ewa inertia: 91654.06792357456
# Minibatch step 14728/802009: mean batch inertia: 91518.752, ewa inertia: 91654.0341793423
# Minibatch step 14729/802009: mean batch inertia: 90393.392, ewa inertia: 91653.71980834023
# Minibatch step 14730/802009: mean batch inertia: 89937.952, ewa inertia: 91653.29194097703
# Minibatch step 14731/802009: mean batch inertia: 91826.664, ewa inertia: 91653.3351754085
# Minibatch step 14732/802009: mean batch inertia: 90450.48, ewa inertia: 91653.03521496529
# Minibatch step 14733/802009: mean batch inertia: 89921.192, ewa inertia: 91652.60333881849
# Minibatch step 14734/802009: mean batch inertia: 91779.2, ewa inertia: 91652.63490869603
# Minibatch step 14735/802009: mean batch inertia: 91385.704, ewa inertia: 91652.56834314822
# Minibatch step 14736/802009: mean batch inertia: 92522.48, ewa inertia: 91652.78527623498
# Minibatch step 14737/802009: mean batch inertia: 91011.632, ewa inertia: 91652.62538947152
# Minibatch step 14738/802009: mean batch inertia: 91192.384, ewa inertia: 91652.51061737427
# Minibatch step 14739/802009: mean batch inertia: 91016.16, ewa inertia: 91652.35192826761
# Minibatch step 14740/802009: mean batch inertia: 91874.704, ewa inertia: 91652.40737702599
# Minibatch step 14741/802009: mean batch inertia: 92884.912, ewa inertia: 91652.71473126156
# Minibatch step 14742/802009: mean batch inertia: 91125.064, ewa inertia: 91652.58314904747
# Minibatch step 14743/802009: mean batch inertia: 91425.312, ewa inertia: 91652.52647360058
# Minibatch step 14744/802009: mean batch inertia: 91475.928, ewa inertia: 91652.48243458616
# Minibatch step 14745/802009: mean batch inertia: 91107.168, ewa inertia: 91652.34644750906
# Minibatch step 14746/802009: mean batch inertia: 90781.408, ewa inertia: 91652.1292583677
# Minibatch step 14747/802009: mean batch inertia: 91408.336, ewa inertia: 91652.06846274133
# Minibatch step 14748/802009: mean batch inertia: 92013.392, ewa inertia: 91652.15856732798
# Minibatch step 14749/802009: mean batch inertia: 89087.984, ewa inertia: 91651.5191296339
# Minibatch step 14750/802009: mean batch inertia: 90492.256, ewa inertia: 91651.23003990036
# Minibatch step 14751/802009: mean batch inertia: 91122.272, ewa inertia: 91651.09813167788
# Minibatch step 14752/802009: mean batch inertia: 92282.88, ewa inertia: 91651.25568145867
# Minibatch step 14753/802009: mean batch inertia: 91869.776, ewa inertia: 91651.31017467858
# Minibatch step 14754/802009: mean batch inertia: 92043.888, ewa inertia: 91651.40807326262
# Minibatch step 14755/802009: mean batch inertia: 91843.296, ewa inertia: 91651.4559250645
# Minibatch step 14756/802009: mean batch inertia: 90939.272, ewa inertia: 91651.27832512547
# Minibatch step 14757/802009: mean batch inertia: 91568.968, ewa inertia: 91651.25779909531
# Minibatch step 14758/802009: mean batch inertia: 89404.6, ewa inertia: 91650.6975417319
# Minibatch step 14759/802009: mean batch inertia: 90676.24, ewa inertia: 91650.45453765121
# Minibatch step 14760/802009: mean batch inertia: 91690.016, ewa inertia: 91650.46440323937
# Minibatch step 14761/802009: mean batch inertia: 92451.672, ewa inertia: 91650.6642033406
# Minibatch step 14762/802009: mean batch inertia: 90867.92, ewa inertia: 91650.46900752405
# Minibatch step 14763/802009: mean batch inertia: 91145.136, ewa inertia: 91650.34299076325
# Minibatch step 14764/802009: mean batch inertia: 92056.808, ewa inertia: 91650.44435244569
# Minibatch step 14765/802009: mean batch inertia: 91052.136, ewa inertia: 91650.29515007931
# Minibatch step 14766/802009: mean batch inertia: 91371.352, ewa inertia: 91650.22558899446
# Minibatch step 14767/802009: mean batch inertia: 92084.776, ewa inertia: 91650.3339544374
# Minibatch step 14768/802009: mean batch inertia: 90219.168, ewa inertia: 91649.97705929095
# Minibatch step 14769/802009: mean batch inertia: 92205.216, ewa inertia: 91650.11552127883
# Minibatch step 14770/802009: mean batch inertia: 90465.472, ewa inertia: 91649.82010234316
# Minibatch step 14771/802009: mean batch inertia: 89979.632, ewa inertia: 91649.4036013598
# Minibatch step 14772/802009: mean batch inertia: 91848.8, ewa inertia: 91649.45332557707
# Minibatch step 14773/802009: mean batch inertia: 91295.768, ewa inertia: 91649.3651257595
# Minibatch step 14774/802009: mean batch inertia: 92193.656, ewa inertia: 91649.50085758757
# Minibatch step 14775/802009: mean batch inertia: 90989.368, ewa inertia: 91649.33623781572
# Minibatch step 14776/802009: mean batch inertia: 90433.008, ewa inertia: 91649.03291754512
# Minibatch step 14777/802009: mean batch inertia: 91578.936, ewa inertia: 91649.01543721757
# Minibatch step 14778/802009: mean batch inertia: 91561.352, ewa inertia: 91648.99357626204
# Minibatch step 14779/802009: mean batch inertia: 90911.616, ewa inertia: 91648.80969368905
# Minibatch step 14780/802009: mean batch inertia: 92179.608, ewa inertia: 91648.94206082556
# Minibatch step 14781/802009: mean batch inertia: 90543.56, ewa inertia: 91648.66640761339
# Minibatch step 14782/802009: mean batch inertia: 90606.48, ewa inertia: 91648.40651373495
# Minibatch step 14783/802009: mean batch inertia: 90922.688, ewa inertia: 91648.22553862551
# Minibatch step 14784/802009: mean batch inertia: 91145.68, ewa inertia: 91648.10021698615
# Minibatch step 14785/802009: mean batch inertia: 89290.872, ewa inertia: 91647.51238626875
# Minibatch step 14786/802009: mean batch inertia: 90894.168, ewa inertia: 91647.3245219933
# Minibatch step 14787/802009: mean batch inertia: 90288.296, ewa inertia: 91646.98561602514
# Minibatch step 14788/802009: mean batch inertia: 92709.296, ewa inertia: 91647.25052829395
# Minibatch step 14789/802009: mean batch inertia: 91579.984, ewa inertia: 91647.23375379105
# Minibatch step 14790/802009: mean batch inertia: 91110.976, ewa inertia: 91647.10002521191
# Minibatch step 14791/802009: mean batch inertia: 90976.112, ewa inertia: 91646.93269844676
# Minibatch step 14792/802009: mean batch inertia: 90333.096, ewa inertia: 91646.60506213075
# Minibatch step 14793/802009: mean batch inertia: 91801.44, ewa inertia: 91646.64367389178
# Minibatch step 14794/802009: mean batch inertia: 92239.968, ewa inertia: 91646.79163337307
# Minibatch step 14795/802009: mean batch inertia: 91741.456, ewa inertia: 91646.81524017623
# Minibatch step 14796/802009: mean batch inertia: 91387.872, ewa inertia: 91646.75066654287
# Minibatch step 14797/802009: mean batch inertia: 91179.664, ewa inertia: 91646.63418741357
# Minibatch step 14798/802009: mean batch inertia: 91677.152, ewa inertia: 91646.64179775334
# Minibatch step 14799/802009: mean batch inertia: 90428.192, ewa inertia: 91646.33794842148
# Minibatch step 14800/802009: mean batch inertia: 90392.728, ewa inertia: 91646.02533107284
# Minibatch step 14801/802009: mean batch inertia: 91083.56, ewa inertia: 91645.88506701325
# Minibatch step 14802/802009: mean batch inertia: 90834.504, ewa inertia: 91645.68272991612
# Minibatch step 14803/802009: mean batch inertia: 90972.24, ewa inertia: 91645.5147910122
# Minibatch step 14804/802009: mean batch inertia: 90359.208, ewa inertia: 91645.194019931
# Minibatch step 14805/802009: mean batch inertia: 91442.48, ewa inertia: 91645.14346838622
# Minibatch step 14806/802009: mean batch inertia: 90295.536, ewa inertia: 91644.80691178102
# Minibatch step 14807/802009: mean batch inertia: 91801.952, ewa inertia: 91644.84609963279
# Minibatch step 14808/802009: mean batch inertia: 90584.96, ewa inertia: 91644.5817919167
# Minibatch step 14809/802009: mean batch inertia: 90964.224, ewa inertia: 91644.41212857819
# Minibatch step 14810/802009: mean batch inertia: 91638.184, ewa inertia: 91644.41057544673
# Minibatch step 14811/802009: mean batch inertia: 91226.408, ewa inertia: 91644.30633659873
# Minibatch step 14812/802009: mean batch inertia: 92916.512, ewa inertia: 91644.62359122957
# Minibatch step 14813/802009: mean batch inertia: 91209.36, ewa inertia: 91644.51504793824
# Minibatch step 14814/802009: mean batch inertia: 91344.288, ewa inertia: 91644.44017920908
# Minibatch step 14815/802009: mean batch inertia: 92069.92, ewa inertia: 91644.54628268539
# Minibatch step 14816/802009: mean batch inertia: 90449.048, ewa inertia: 91644.24815685774
# Minibatch step 14817/802009: mean batch inertia: 91892.432, ewa inertia: 91644.31004738047
# Minibatch step 14818/802009: mean batch inertia: 90847.448, ewa inertia: 91644.11133094494
# Minibatch step 14819/802009: mean batch inertia: 90413.28, ewa inertia: 91643.80439398438
# Minibatch step 14820/802009: mean batch inertia: 90219.296, ewa inertia: 91643.4491590584
# Minibatch step 14821/802009: mean batch inertia: 90697.472, ewa inertia: 91643.21325723604
# Minibatch step 14822/802009: mean batch inertia: 90593.528, ewa inertia: 91642.95149334175
# Minibatch step 14823/802009: mean batch inertia: 91055.968, ewa inertia: 91642.80511509738
# Minibatch step 14824/802009: mean batch inertia: 91917.328, ewa inertia: 91642.87357388435
# Minibatch step 14825/802009: mean batch inertia: 90136.128, ewa inertia: 91642.4978311687
# Minibatch step 14826/802009: mean batch inertia: 91577.776, ewa inertia: 91642.48169124633
# Minibatch step 14827/802009: mean batch inertia: 92546.664, ewa inertia: 91642.70717053229
# Minibatch step 14828/802009: mean batch inertia: 92626.248, ewa inertia: 91642.95243974602
# Minibatch step 14829/802009: mean batch inertia: 91318.832, ewa inertia: 91642.87161263337
# Minibatch step 14830/802009: mean batch inertia: 91473.288, ewa inertia: 91642.82932294077
# Minibatch step 14831/802009: mean batch inertia: 90359.744, ewa inertia: 91642.50935520898
# Minibatch step 14832/802009: mean batch inertia: 91444.656, ewa inertia: 91642.46001578614
# Minibatch step 14833/802009: mean batch inertia: 92521.32, ewa inertia: 91642.67918035039
# Minibatch step 14834/802009: mean batch inertia: 91722.768, ewa inertia: 91642.6991523955
# Minibatch step 14835/802009: mean batch inertia: 90521.152, ewa inertia: 91642.41946803467
# Minibatch step 14836/802009: mean batch inertia: 90093.456, ewa inertia: 91642.03319728664
# Minibatch step 14837/802009: mean batch inertia: 90629.712, ewa inertia: 91641.78075100614
# Minibatch step 14838/802009: mean batch inertia: 91008.688, ewa inertia: 91641.62287432567
# Minibatch step 14839/802009: mean batch inertia: 91623.136, ewa inertia: 91641.61826418544
# Minibatch step 14840/802009: mean batch inertia: 92829.712, ewa inertia: 91641.91454351385
# Minibatch step 14841/802009: mean batch inertia: 92251.92, ewa inertia: 91642.0666628303
# Minibatch step 14842/802009: mean batch inertia: 90694.976, ewa inertia: 91641.83048332941
# Minibatch step 14843/802009: mean batch inertia: 92292.528, ewa inertia: 91641.99275017538
# Minibatch step 14844/802009: mean batch inertia: 91913.368, ewa inertia: 91642.06042402497
# Minibatch step 14845/802009: mean batch inertia: 91042.968, ewa inertia: 91641.91102613175
# Minibatch step 14846/802009: mean batch inertia: 92302.28, ewa inertia: 91642.07570478479
# Minibatch step 14847/802009: mean batch inertia: 92229.544, ewa inertia: 91642.222203926
# Minibatch step 14848/802009: mean batch inertia: 90721.968, ewa inertia: 91641.9927167321
# Minibatch step 14849/802009: mean batch inertia: 90807.488, ewa inertia: 91641.78461320493
# Converged (lack of improvement in inertia) at step 14849/802009
# SVM Results:
#   Accuracy : 0.3660
#   Precision: 0.1020
#   Recall   : 0.0878
#   F1-score : 0.0850
# [ORB | KMEANS | k=500 | SVM] Accuracy: 0.3660, F1: 0.0850
# NB Results:
#   Accuracy : 0.1010
#   Precision: 0.0793
#   Recall   : 0.1230
#   F1-score : 0.0673
# [ORB | KMEANS | k=500 | NB] Accuracy: 0.1010, F1: 0.0673
# Initialization 0
#   Iteration 10
# Initialization converged.
# SVM Results:
#   Accuracy : 0.4735
#   Precision: 0.0430
#   Recall   : 0.0597
#   F1-score : 0.0453
# [ORB | GMM | k=100 | SVM] Accuracy: 0.4735, F1: 0.0453
# NB Results:
#   Accuracy : 0.1065
#   Precision: 0.0720
#   Recall   : 0.1152
#   F1-score : 0.0615
# [ORB | GMM | k=100 | NB] Accuracy: 0.1065, F1: 0.0615
# Initialization 0
#   Iteration 10
# Initialization converged.
# SVM Results:
#   Accuracy : 0.4700
#   Precision: 0.0529
#   Recall   : 0.0604
#   F1-score : 0.0479
# [ORB | GMM | k=250 | SVM] Accuracy: 0.4700, F1: 0.0479
# NB Results:
#   Accuracy : 0.1000
#   Precision: 0.1014
#   Recall   : 0.1299
#   F1-score : 0.0749
# [ORB | GMM | k=250 | NB] Accuracy: 0.1000, F1: 0.0749
# Initialization 0
#   Iteration 10
#   Iteration 20
# Initialization converged.
# SVM Results:
#   Accuracy : 0.3455
#   Precision: 0.0804
#   Recall   : 0.0730
#   F1-score : 0.0704
# [ORB | GMM | k=500 | SVM] Accuracy: 0.3455, F1: 0.0704
# NB Results:
#   Accuracy : 0.1005
#   Precision: 0.0892
#   Recall   : 0.1295
#   F1-score : 0.0714
# [ORB | GMM | k=500 | NB] Accuracy: 0.1005, F1: 0.0714
#
# Saved results'

# %%
##choose run with the highest f1
best_idx = df['f1'].idxmax()
best_config = df.loc[best_idx]
print("Best on val:", best_config.to_dict())
# Out:
# Best on val: {'feature': 'sift', 'clustering': 'kmeans', 'vocab_size': 500, 'classifier': 'svm', 'accuracy': 0.3595, 'precision': 0.11303748918817921, 'recall': 0.10753103731911964, 'f1': 0.10731922387378179}

# %%
#test the best model
#get descriptors on test set
if feature_method == 'sift':
    _, image_descriptors_test = get_sift_descriptors(image_paths_test)
else:  # orb
    _, image_descriptors_test = get_orb_descriptors(image_paths_test)

#get best hyperparams
feat   = best_config['feature']
clust  = best_config['clustering']
k      = int(best_config['vocab_size'])
clf_nm = best_config['classifier']

# merge train and val and get descriptors
paths_tv  = image_paths_train + image_paths_val
labels_tv = y_train + y_val

if feat == 'sift':
    all_desc_tv, descs_tv = get_sift_descriptors(paths_tv)
else:
    all_desc_tv, descs_tv = get_orb_descriptors(paths_tv)

all_desc_tv = np.array(all_desc_tv, dtype=np.float32)

# cluster to get codebook
if clust == 'kmeans':
    clust_model = MiniBatchKMeans(n_clusters=k, random_state=42, batch_size=1000)
    clust_model.fit(all_desc_tv)
else:  # GMM + PCA
    sample_size = 100000
    if len(all_desc_tv) > sample_size:
        indices = np.random.choice(len(all_desc_tv), sample_size, replace=False)
        sampled_descriptors = all_desc_tv[indices]
    else:
        sampled_descriptors = all_desc_tv
    pca = PCA(n_components=64 if feat=='sift' else 16, random_state=42)
    pca_all = pca.fit_transform(sampled_descriptors)

    clust_model = GaussianMixture(n_components=k, covariance_type='diag', random_state=42)
    clust_model.fit(pca_all)

def make_hist(d):
return build_histograms_kmeans(d.astype(np.float32), clust_model, k) if len(d)>0 else np.zeros(k)

def make_hist(d):
    if d is None or len(d)==0:
        return np.zeros(k)
    d_pca = pca.transform(d.astype(np.float32))
    return build_histograms_gmm(d_pca, clust_model, k)

# feature matrices for train+val and test
X_tv   = np.vstack([make_hist(d) for d in descs_tv])
X_test = np.vstack([make_hist(d) for d in image_descriptors_test])

#train classifier and evaluate on test
if clf_nm == 'svm':
    final_clf = SVC(random_state=42)
elif clf_nm == 'nb':
    final_clf = GaussianNB()

final_clf.fit(X_tv, labels_tv)
y_pred = final_clf.predict(X_test)

from sklearn.metrics import accuracy_score, f1_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

test_acc = accuracy_score(y_test, y_pred)
test_f1  = f1_score(y_test, y_pred, average='weighted')

cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(xticks_rotation='vertical')
plt.title("Confusion Matrix")
plt.show()

print(f"\nFINAL TEST → Acc: {test_acc:.4f}, F1: {test_f1:.4f}")
# Out:
# Extracting ORB descriptors: 100%|██████████| 2000/2000 [00:20<00:00, 98.75it/s]
# Extracting SIFT descriptors: 100%|██████████| 10000/10000 [04:02<00:00, 41.29it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-06a42736ad4f> in <cell line: 0>()
#      54 # --- 5) Build feature matrices for train+val and test ---
#      55 X_tv   = np.vstack([make_hist(d) for d in descs_tv])
# ---> 56 X_test = np.vstack([make_hist(d) for d in image_descriptors_test])
#      57
#      58 # --- 6) Train the final classifier & evaluate on test ---
#
# <ipython-input-52-06a42736ad4f> in <listcomp>(.0)
#      54 # --- 5) Build feature matrices for train+val and test ---
#      55 X_tv   = np.vstack([make_hist(d) for d in descs_tv])
# ---> 56 X_test = np.vstack([make_hist(d) for d in image_descriptors_test])
#      57
#      58 # --- 6) Train the final classifier & evaluate on test ---
#
# <ipython-input-52-06a42736ad4f> in make_hist(d)
#      31     clust_model.fit(all_desc_tv)
#      32     def make_hist(d):
# ---> 33         return build_histograms_kmeans(d.astype(np.float32), clust_model, k) if len(d)>0 else np.zeros(k)
#      34
#      35 else:  # GMM + PCA
#
# <ipython-input-39-e6ab66f5ca70> in build_histograms_kmeans(descriptors, kmeans, k)
#       4     hist = np.zeros(k)
#       5     if descriptors is not None and len(descriptors) > 0:
# ----> 6         words_in_image = kmeans.predict(descriptors)
#       7         #update histogram (word is an id)
#       8         for word in words_in_image:
#
# /usr/local/lib/python3.11/dist-packages/sklearn/cluster/_kmeans.py in predict(self, X)
#    1083         check_is_fitted(self)
#    1084
# -> 1085         X = self._check_test_data(X)
#    1086
#    1087         # sample weights are not used by predict but cython helpers expect an array
#
# /usr/local/lib/python3.11/dist-packages/sklearn/cluster/_kmeans.py in _check_test_data(self, X)
#     942
#     943     def _check_test_data(self, X):
# --> 944         X = validate_data(
#     945             self,
#     946             X,
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2963
#    2964     if not no_val_X and check_params.get("ensure_2d", True):
# -> 2965         _check_n_features(_estimator, X, reset=reset)
#    2966
#    2967     return out
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py in _check_n_features(estimator, X, reset)
#    2827
#    2828     if n_features != estimator.n_features_in_:
# -> 2829         raise ValueError(
#    2830             f"X has {n_features} features, but {estimator.__class__.__name__} "
#    2831             f"is expecting {estimator.n_features_in_} features as input."
#
# ValueError: X has 32 features, but MiniBatchKMeans is expecting 128 features as input.

# %%
#precision
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score



precision = precision_score(y_test, y_pred, average='weighted')
print(f"Precision: {precision:.4f}")
recall = recall_score(y_test, y_pred, average='weighted')
print(f"Recall: {recall:.4f}")

precision_micro = precision_score(y_test, y_pred, average='micro', zero_division=0)
recall_micro = recall_score(y_test, y_pred, average='micro', zero_division=0)
print(f"Micro-averaged Precision: {precision_micro:.4f}")
print(f"Micro-averaged Recall: {recall_micro:.4f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-ac8d56a6faff> in <cell line: 0>()
#       2 from sklearn.metrics import precision_score
#       3
# ----> 4 precision = precision_score(y_test, y_pred, average='weighted')
#       5 print(f"Precision: {precision:.4f}")
#       6 #recall
#
# NameError: name 'y_test' is not defined
